# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.linspace(0,1,10)

beta_true = np.array([1,1])

t = beta_true[0] + beta_true[1]*x + np.random.normal(0,.1,len(x))

# %%
plt.scatter(x, t, c='r')
plt.show()

# %% [markdown]
# Implementation de la descente du gradient

# %%
n = len(x)  # nombre d'observations
beta = np.random.normal(0, 1, (2,))
max_iter = 100
eps = 0.1
loss = []

for iter in range(max_iter):
    grad = np.zeros((2,))
    loss_iter = 0
    
    for i in range(n):
        r = t[i] - (beta[0] + beta[1]*x[i])  # résidu
        grad += (-2/n) * r * np.array([1, x[i]])
        loss_iter += (1/n) * r**2
    
    loss.append(loss_iter)
    beta -= eps * grad

print("Beta final =", beta)
# Out:
# Beta final = [1.05589165e+76 7.02241533e+76]

# %%
xtest = np.linspace(0,1,100)

pred = beta[0] + beta[1]*xtest

# %%
plt.plot(xtest, pred, c='g')
plt.scatter(x, t, c='r')
plt.show()

# %%
plt.semilogy(loss)
plt.show()

# %% [markdown]
# Gradient Stochastique

# %%
import numpy as np

# Données simulées
x = np.linspace(0, 10, 100)
beta_true = np.array([1, 1])
t = beta_true[0] + beta_true[1]*x + np.random.normal(0, 0.1, len(x))

# Initialisation des paramètres
beta = np.random.normal(0, 1, (2,))
epochs = 20
eps = 0.01
n = len(x)

# SGD
for epoch in range(epochs):
    arr = np.arange(n)
    np.random.shuffle(arr)   # mélanger les indices
    
    for i in arr:
        # prédiction
        y_pred = beta[0] + beta[1] * x[i]
        
        # résidu
        r = t[i] - y_pred
        
        # gradient (par rapport à beta0 et beta1)
        grad = (-2/n) * r * np.array([1, x[i]])
        
        # mise à jour des paramètres
        beta -= eps * grad
    
    print(f"Epoch {epoch+1}, beta = {beta}")
# Out:
# Epoch 1, beta = [-0.62191794 -0.05821506]
# Epoch 2, beta = [-0.51896263  0.57288476]
# Epoch 3, beta = [-0.46352583  0.88888208]
# Epoch 4, beta = [-0.43222659  1.04747379]
# Epoch 5, beta = [-0.41294496  1.12732439]
# Epoch 6, beta = [-0.39982053  1.1661713 ]
# Epoch 7, beta = [-0.38983478  1.18422634]
# Epoch 8, beta = [-0.38104153  1.19491199]
# Epoch 9, beta = [-0.37316085  1.19975474]
# Epoch 10, beta = [-0.36581121  1.20125464]
# Epoch 11, beta = [-0.35865206  1.20171925]
# Epoch 12, beta = [-0.35177406  1.20054614]
# Epoch 13, beta = [-0.34480223  1.20022138]
# Epoch 14, beta = [-0.33769921  1.20105328]
# Epoch 15, beta = [-0.33109018  1.19879452]
# Epoch 16, beta = [-0.32422316  1.19849282]
# Epoch 17, beta = [-0.31733355  1.19858008]
# Epoch 18, beta = [-0.31089885  1.19583336]
# Epoch 19, beta = [-0.30448937  1.19315511]
# Epoch 20, beta = [-0.29788849  1.19196019]

# %%
plt.figure(figsize=(8,5))
plt.scatter(x, t, label="Données bruyantes", alpha=0.6)

# droite vraie
plt.plot(x, beta_true[0] + beta_true[1]*x, "g--", label="Droite vraie (beta_true)")

# droite estimée après entraînement
plt.plot(x, beta[0] + beta[1]*x, "r-", label="Droite estimée (SGD)")

plt.xlabel("x")
plt.ylabel("t")
plt.title("Régression linéaire avec SGD")
plt.legend()
plt.show()
